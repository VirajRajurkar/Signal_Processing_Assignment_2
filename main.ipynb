# %% [markdown]
# # Individual Assignment #2: Add, Multiply, Synthesize!
# ## By Viraj Rajurkar: s215221
#
# ### Introduction
#
# Basic components of a synthesizer
#
# tell a story introducing the assignment

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### a. A function generating sinusoids/trains of square waves or triangle waves or saw tooth waves
#
# Blah blah blah

# %%
import numpy as np
import matplotlib.pyplot as plt

fs = 44100           # Sampling rate (samples per second)
f = 100              # Frequency (Hz)
duration = 10.0      # seconds

t = np.linspace(0, duration, int(fs*duration), endpoint=False)
sin_wave = np.sin(2 * np.pi * f * t)

plt.plot(t[:1000], sin_wave[:1000])   # plot first 1000 samples (~23 ms)
plt.title("Sine wave at 440 Hz")
plt.xlabel("Time in seconds")
plt.ylabel("Amplitude")
plt.show()

# %%
# Generating a square wave

square_wave = np.sign(np.sin(2 * np.pi * f * t))
plt.plot(t[:1000], square_wave[:1000])
plt.title("Square wave at 440 Hz")
plt.xlabel("Time in seconds")
plt.ylabel("Amplitude")
plt.show()

# %%
# Generating a triangle wave

from scipy import signal

triangle_wave = signal.sawtooth(2 * np.pi * f * t, width=0.5)
plt.plot(t[:1000], triangle_wave[:1000])
plt.title("Triangle wave (440 Hz)")
plt.xlabel("Time in seconds")
plt.ylabel("Amplitude")
plt.show()

# %%
# Generating a sawtooth wave

sawtooth_wave = signal.sawtooth(2 * np.pi * f * t)
plt.plot(t[:1000], sawtooth_wave[:1000])
plt.title("Sawtooth wave (440 Hz)")
plt.xlabel("Time in seconds")
plt.ylabel("Amplitude")
plt.show()

# %% [markdown]
# ### b. An ADSR-envelope generator with "Attack or Decay or Sustain or Release"
#
# This component of the assignment involves enveloping. Enveloping just means finding a curve of the signal that highlights the peaks of the signal, essentially smoothing it, to reveal its amplitudes over time.
#
# It describes how the loudness of a sound changes over time

# %%
# Insert code here
"""
Different functions for waves; 

one function for ADSR envelope (control the parameters... length of attack, etc AND the volume of the sustain) 
                                                (Doesn't have to be linear, could be exponential)

'function that generates the ADSR envelope given the parameters'
envelope because it describes the amplitude in time

amplitude(y) vs time (x)

for multiple inputs you just need to add the signal vectors together (normalise the amplitudes after so that we dont get clipping)

function to take in A's value
function to take in D's value
function to take in S's value
function to take in R's value
"""

# Copying is ok, but blindly copying without understanding or being able to explain is not ok. 

# ADSR needs to somehow sum up to 100% or whatever duration we had specified before.
# Out:
#   Cell In[1], line 2
#     """
#     ^
# SyntaxError: incomplete input

# %% [markdown]
# ### c. A filter element (low-pass or high-pass or band pass)

# %%
# Insert code here

# %% [markdown]
# ### d. An all-pass filter.
#
# Blah blah blah

# %%
# Insert code here

# %% [markdown]
# ### e. Feedback:
#
# Blah blah blah
#
# Too many high frequencies? Apply a low-pass filter!
#
# Not enough "oomph"? Boost lower frequenciesor modulate with a low-frequency sound.
#
# Needs to be "rough"? Try square wave instead of sinuisoid.
#
# More techno-like? Send a pulse train through a cascade of many(!) all-pass filters!

# %% [markdown]
# ### Bibliography
#
# 1. Source 1
#
# 2. Source 2
#
# 3. Source 3

# %%
# Insert code here

# %% [markdown]
# ### Conclusion
#
# Blah blah blah
